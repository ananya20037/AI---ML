# %%
#Title:  DBSCAN Clustering for Anomaly Detection

# Task 1: DBSCAN on Uniform Data

# 1. Generate a dataset with points [(-1, -1), (0, 0), (1, 1), (9, 9), (10, 10)] .
# 2. Apply DBSCAN with a small eps (e.g., 0.5) and a minimum number of points (e.g., 2).
# 3. Identify which points are treated as noise/outliers.





# Task 2: Detecting Anomalies in a Simple Dataset

# 1. Use the dataset: [(0, 0), (0, 1), (1, 0), (10, 10), (11, 11)] .
# 2. Configure DBSCAN parameters ( eps=1 , min_samples=2 ) and apply it.
# 3. Analyze the resulting clusters and classify any points identified as outliers.



# Task 3: Exploring Real World Data

# 1. Load a dataset with anomalies like credit card transactions.
# 2. Apply DBSCAN to detect unusual transactions by adjusting eps and min_samples .
# 3. Identify and discuss the points that are marked as noise, understanding why they might be considered anomalies.

import numpy as np
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Task 1: DBSCAN on Uniform Data

# Create a uniform dataset
data_1 = np.array([[-1, -1], [0, 0], [1, 1], [9, 9], [10, 10]])

# Apply DBSCAN
dbscan_1 = DBSCAN(eps=0.5, min_samples=2)
labels_1 = dbscan_1.fit_predict(data_1)

# Points marked as -1 are noise/outliers
outliers_1 = data_1[labels_1 == -1]

# Visualize the results for Task 1
plt.scatter(data_1[:, 0], data_1[:, 1], c=labels_1, cmap='rainbow')
plt.title("DBSCAN on Uniform Data (Task 1)")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

print("Outliers in Task 1:", outliers_1)

# Task 2: DBSCAN on Simple Data

# Create a simple dataset
data_2 = np.array([[0, 0], [0, 1], [1, 0], [10, 10], [11, 11]])

# Apply DBSCAN
dbscan_2 = DBSCAN(eps=1, min_samples=2)
labels_2 = dbscan_2.fit_predict(data_2)

# Points marked as -1 are noise/outliers
outliers_2 = data_2[labels_2 == -1]

# Visualize the results for Task 2
plt.scatter(data_2[:, 0], data_2[:, 1], c=labels_2, cmap='rainbow')
plt.title("DBSCAN on Simple Data (Task 2)")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

print("Outliers in Task 2:", outliers_2)
# Out:
# Outliers in Task 1: [[-1 -1]
#  [ 0  0]
#  [ 1  1]
#  [ 9  9]
#  [10 10]]
# Outliers in Task 2: [[10 10]
#  [11 11]]
